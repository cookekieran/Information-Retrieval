# %%
import ir_datasets
import json
import os
from itertools import islice

import spacy
import pickle
from tqdm import tqdm

# %%
dataset = ir_datasets.load("cord19/trec-covid/round1")

# %%
# documents metadata
print(dataset.docs_cls()._fields)
# Out:
# ('doc_id', 'title', 'doi', 'date', 'abstract')

# %%
for doc in islice(dataset.docs_iter(), 3): # look at first 3 documents
    print(f"ID: {doc.doc_id}")    
    print(f"Title: {doc.title}")
    print(f"Abstract: {doc.abstract}")
    print(f"Link: {doc.doi}")
    print(f"date: {doc.date}")
    print("-" * 20)
# Out:
# ID: xqhn0vbp
# Title: Airborne rhinovirus detection and effect of ultraviolet irradiation on detection by a semi-nested RT-PCR assay
# Abstract: BACKGROUND: Rhinovirus, the most common cause of upper respiratory tract infections, has been implicated in asthma exacerbations and possibly asthma deaths. Although the method of transmission of rhinoviruses is disputed, several studies have demonstrated that aerosol transmission is a likely method of transmission among adults. As a first step in studies of possible airborne rhinovirus transmission, we developed methods to detect aerosolized rhinovirus by extending existing technology for detecting infectious agents in nasal specimens. METHODS: We aerosolized rhinovirus in a small aerosol chamber. Experiments were conducted with decreasing concentrations of rhinovirus. To determine the effect of UV irradiation on detection of rhinoviral aerosols, we also conducted experiments in which we exposed aerosols to a UV dose of 684 mJ/m(2). Aerosols were collected on Teflon filters and rhinovirus recovered in Qiagen AVL buffer using the Qiagen QIAamp Viral RNA Kit (Qiagen Corp., Valencia, California) followed by semi-nested RT-PCR and detection by gel electrophoresis. RESULTS: We obtained positive results from filter samples that had collected at least 1.3 TCID(50 )of aerosolized rhinovirus. Ultraviolet irradiation of airborne virus at doses much greater than those used in upper-room UV germicidal irradiation applications did not inhibit subsequent detection with the RT-PCR assay. CONCLUSION: The air sampling and extraction methodology developed in this study should be applicable to the detection of rhinovirus and other airborne viruses in the indoor air of offices and schools. This method, however, cannot distinguish UV inactivated virus from infectious viral particles.
# Link: 10.1186/1471-2458-3-5
# date: 2003-01-13
# --------------------
# ID: gi6uaa83
# Title: Discovering human history from stomach bacteria
# Abstract: Recent analyses of human pathogens have revealed that their evolutionary histories are congruent with the hypothesized pattern of ancient and modern human population migrations. Phylogenetic trees of strains of the bacterium Helicobacter pylori and the polyoma JC virus taken from geographically diverse groups of human beings correlate closely with relationships of the populations in which they are found.
# Link: 10.1186/gb-2003-4-5-213
# date: 2003-04-28
# --------------------
# ID: le0ogx1s
# Title: A new recruit for the army of the men of death
# Abstract: The army of the men of death, in John Bunyan's memorable phrase, has a new recruit, and fear has a new face: a face wearing a surgical mask.
# Link: 10.1186/gb-2003-4-7-113
# date: 2003-06-27
# --------------------

# %%
doc_store = dataset.docs_store()
query_store = {q.query_id: q for q in dataset.queries_iter()}

count = 0
for qrel in dataset.qrels_iter():
    if qrel.relevance == 2:
        print("query relevance == 2")
        query = query_store[qrel.query_id]
        doc = doc_store.get(qrel.doc_id)
        
        print(f"SAMPLE {count + 1}")
        print(f"QUERY ID:    {query.query_id}")
        print(f"QUERY TITLE: {query.title}")
        print(f"QUERY DESC:  {query.description}")
        print("-" * 30)
        print(f"MATCHING DOC ID: {doc.doc_id}")
        print(f"DOC TITLE:       {doc.title}")
        print(f"DOC ABSTRACT:    {doc.abstract[:300]}...") # Truncated for readability
        print("\n" + "="*50 + "\n")
        
        count += 1
        if count >= 6:
            break
    
    elif qrel.relevance == 1:
        print("query relevance == 1")
        query = query_store[qrel.query_id]
        doc = doc_store.get(qrel.doc_id)
        
        print(f"SAMPLE {count + 1}")
        print(f"QUERY ID:    {query.query_id}")
        print(f"QUERY TITLE: {query.title}")
        print(f"QUERY DESC:  {query.description}")
        print("-" * 30)
        print(f"MATCHING DOC ID: {doc.doc_id}")
        print(f"DOC TITLE:       {doc.title}")
        print(f"DOC ABSTRACT:    {doc.abstract[:300]}...") # Truncated for readability
        print("\n" + "="*50 + "\n")

        count += 1
        if count >=3:
            continue
# Out:
# query relevance == 2
# SAMPLE 1
# QUERY ID:    1
# QUERY TITLE: coronavirus origin
# QUERY DESC:  what is the origin of COVID-19
# ------------------------------
# MATCHING DOC ID: 010vptx3
# DOC TITLE:       The SARS, MERS and novel coronavirus (COVID-19) epidemics, the newest and biggest global health threats: what lessons have we learned?
# DOC ABSTRACT:    To provide an overview of the three major deadly coronaviruses and identify areas for improvement of future preparedness plans, as well as provide a critical assessment of the risk factors and actionable items for stopping their spread, utilizing lessons learned from the first two deadly coronavirus...
#
# ==================================================
#
# query relevance == 1
# SAMPLE 2
# QUERY ID:    1
# QUERY TITLE: coronavirus origin
# QUERY DESC:  what is the origin of COVID-19
# ------------------------------
# MATCHING DOC ID: 02f0opkr
# DOC TITLE:       An outbreak of <scp>COVID</scp> ‐19 caused by a new coronavirus: what we know so far
# DOC ABSTRACT:    An outbreak of a novel coronavirus, now formally named severe acute respiratory syndrome coronavirus 2 (SARS‐CoV‐2) and causing coronavirus disease 2019 (COVID‐19), emerged in the city of Wuhan in Hubei province in central China in December 2019. The first cases were noted as a cluster of patients w...
#
# ==================================================
#
# query relevance == 2
# SAMPLE 3
# QUERY ID:    1
# QUERY TITLE: coronavirus origin
# QUERY DESC:  what is the origin of COVID-19
# ------------------------------
# MATCHING DOC ID: 0be4wta5
# DOC TITLE:       Understanding the emerging coronavirus: what it means for health security and infection prevention
# DOC ABSTRACT:    ...
#
# ==================================================
#
# query relevance == 1
# SAMPLE 4
# QUERY ID:    1
# QUERY TITLE: coronavirus origin
# QUERY DESC:  what is the origin of COVID-19
# ------------------------------
# MATCHING DOC ID: 0hnh4n9e
# DOC TITLE:       Investigation of three clusters of COVID-19 in Singapore: implications for surveillance and response measures
# DOC ABSTRACT:    Summary Background Three clusters of coronavirus disease 2019 (COVID-19) linked to a tour group from China, a company conference, and a church were identified in Singapore in February, 2020. Methods We gathered epidemiological and clinical data from individuals with confirmed COVID-19, via interview...
#
# ==================================================
#
# query relevance == 2
# SAMPLE 5
# QUERY ID:    1
# QUERY TITLE: coronavirus origin
# QUERY DESC:  what is the origin of COVID-19
# ------------------------------
# MATCHING DOC ID: 0nh58odf
# DOC TITLE:       Genetic diversity and evolution of SARS-CoV-2
# DOC ABSTRACT:    Abstract COVID-19 is a viral respiratory illness caused by a new coronavirus called SARS-CoV-2. The World Health Organization declared the SARS-CoV-2 outbreak a global public health emergency. We performed genetic analyses of eighty-six complete or near-complete genomes of SARS-CoV-2 and revealed ma...
#
# ==================================================
#
# query relevance == 2
# SAMPLE 6
# QUERY ID:    1
# QUERY TITLE: coronavirus origin
# QUERY DESC:  what is the origin of COVID-19
# ------------------------------
# MATCHING DOC ID: 0xhho1sh
# DOC TITLE:       Severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) and coronavirus disease-2019 (COVID-19): The epidemic and the challenges
# DOC ABSTRACT:    ABSTRACT The emergence of severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2; previously provisionally named 2019 novel coronavirus or 2019-nCoV) disease (COVID-19) in China at the end of 2019 has caused a large global outbreak and is a major public health issue. As of 11 February 2020, dat...
#
# ==================================================

# %%
from collections import Counter
import ir_datasets

qrel_counts = Counter(q.query_id for q in dataset.qrels_iter())

print(f"{'Query ID':<10} | {'Total Judgments':<15}")
print("-" * 30)

for q_id in sorted(qrel_counts.keys(), key=int):
    print(f"{q_id:<10} | {qrel_counts[q_id]:<15}")
# Out:
# Query ID   | Total Judgments
# ------------------------------
# 1          | 323
# 2          | 284
# 3          | 337
# 4          | 357
# 5          | 336
# 6          | 321
# 7          | 275
# 8          | 360
# 9          | 298
# 10         | 191
# 11         | 344
# 12         | 324
# 13         | 373
# 14         | 222
# 15         | 348
# 16         | 340
# 17         | 243
# 18         | 267
# 19         | 301
# 20         | 247
# 21         | 319
# 22         | 259
# 23         | 256
# 24         | 249
# 25         | 308
# 26         | 312
# 27         | 300
# 28         | 180
# 29         | 218
# 30         | 199

# %%
doc_lengths = {}
inverted_index = {}
total_len = 0
N = 0

# build index
for doc in dataset.docs_iter():
    break

for doc in dataset.docs_iter():
    doc_id = doc.doc_id
    title = doc.title
    doi = doc.doi
    date = doc.date
    abstract = doc.abstract
    
    print(abstract.lower().split())
    break
# Out:
# ['background:', 'rhinovirus,', 'the', 'most', 'common', 'cause', 'of', 'upper', 'respiratory', 'tract', 'infections,', 'has', 'been', 'implicated', 'in', 'asthma', 'exacerbations', 'and', 'possibly', 'asthma', 'deaths.', 'although', 'the', 'method', 'of', 'transmission', 'of', 'rhinoviruses', 'is', 'disputed,', 'several', 'studies', 'have', 'demonstrated', 'that', 'aerosol', 'transmission', 'is', 'a', 'likely', 'method', 'of', 'transmission', 'among', 'adults.', 'as', 'a', 'first', 'step', 'in', 'studies', 'of', 'possible', 'airborne', 'rhinovirus', 'transmission,', 'we', 'developed', 'methods', 'to', 'detect', 'aerosolized', 'rhinovirus', 'by', 'extending', 'existing', 'technology', 'for', 'detecting', 'infectious', 'agents', 'in', 'nasal', 'specimens.', 'methods:', 'we', 'aerosolized', 'rhinovirus', 'in', 'a', 'small', 'aerosol', 'chamber.', 'experiments', 'were', 'conducted', 'with', 'decreasing', 'concentrations', 'of', 'rhinovirus.', 'to', 'determine', 'the', 'effect', 'of', 'uv', 'irradiation', 'on', 'detection', 'of', 'rhinoviral', 'aerosols,', 'we', 'also', 'conducted', 'experiments', 'in', 'which', 'we', 'exposed', 'aerosols', 'to', 'a', 'uv', 'dose', 'of', '684', 'mj/m(2).', 'aerosols', 'were', 'collected', 'on', 'teflon', 'filters', 'and', 'rhinovirus', 'recovered', 'in', 'qiagen', 'avl', 'buffer', 'using', 'the', 'qiagen', 'qiaamp', 'viral', 'rna', 'kit', '(qiagen', 'corp.,', 'valencia,', 'california)', 'followed', 'by', 'semi-nested', 'rt-pcr', 'and', 'detection', 'by', 'gel', 'electrophoresis.', 'results:', 'we', 'obtained', 'positive', 'results', 'from', 'filter', 'samples', 'that', 'had', 'collected', 'at', 'least', '1.3', 'tcid(50', ')of', 'aerosolized', 'rhinovirus.', 'ultraviolet', 'irradiation', 'of', 'airborne', 'virus', 'at', 'doses', 'much', 'greater', 'than', 'those', 'used', 'in', 'upper-room', 'uv', 'germicidal', 'irradiation', 'applications', 'did', 'not', 'inhibit', 'subsequent', 'detection', 'with', 'the', 'rt-pcr', 'assay.', 'conclusion:', 'the', 'air', 'sampling', 'and', 'extraction', 'methodology', 'developed', 'in', 'this', 'study', 'should', 'be', 'applicable', 'to', 'the', 'detection', 'of', 'rhinovirus', 'and', 'other', 'airborne', 'viruses', 'in', 'the', 'indoor', 'air', 'of', 'offices', 'and', 'schools.', 'this', 'method,', 'however,', 'cannot', 'distinguish', 'uv', 'inactivated', 'virus', 'from', 'infectious', 'viral', 'particles.']

# %%
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner", "attribute_ruler"])

# %%
print(abstract)
print("="*30)

processed_abstract = [
    token.lemma_.lower() 
    for token in nlp(abstract) 
    if not token.is_stop and not token.is_punct and token.is_alpha]

print(processed_abstract) # this includes stop word removal - do we want that before doing BM25?
# Out:
# BACKGROUND: Rhinovirus, the most common cause of upper respiratory tract infections, has been implicated in asthma exacerbations and possibly asthma deaths. Although the method of transmission of rhinoviruses is disputed, several studies have demonstrated that aerosol transmission is a likely method of transmission among adults. As a first step in studies of possible airborne rhinovirus transmission, we developed methods to detect aerosolized rhinovirus by extending existing technology for detecting infectious agents in nasal specimens. METHODS: We aerosolized rhinovirus in a small aerosol chamber. Experiments were conducted with decreasing concentrations of rhinovirus. To determine the effect of UV irradiation on detection of rhinoviral aerosols, we also conducted experiments in which we exposed aerosols to a UV dose of 684 mJ/m(2). Aerosols were collected on Teflon filters and rhinovirus recovered in Qiagen AVL buffer using the Qiagen QIAamp Viral RNA Kit (Qiagen Corp., Valencia, California) followed by semi-nested RT-PCR and detection by gel electrophoresis. RESULTS: We obtained positive results from filter samples that had collected at least 1.3 TCID(50 )of aerosolized rhinovirus. Ultraviolet irradiation of airborne virus at doses much greater than those used in upper-room UV germicidal irradiation applications did not inhibit subsequent detection with the RT-PCR assay. CONCLUSION: The air sampling and extraction methodology developed in this study should be applicable to the detection of rhinovirus and other airborne viruses in the indoor air of offices and schools. This method, however, cannot distinguish UV inactivated virus from infectious viral particles.
# ==============================
# ['background', 'rhinovirus', 'common', 'cause', 'upper', 'respiratory', 'tract', 'infection', 'implicate', 'asthma', 'exacerbation', 'possibly', 'asthma', 'death', 'method', 'transmission', 'rhinovirus', 'dispute', 'study', 'demonstrate', 'aerosol', 'transmission', 'likely', 'method', 'transmission', 'adult', 'step', 'study', 'possible', 'airborne', 'rhinovirus', 'transmission', 'develop', 'method', 'detect', 'aerosolized', 'rhinovirus', 'extend', 'exist', 'technology', 'detect', 'infectious', 'agent', 'nasal', 'specimen', 'method', 'aerosolize', 'rhinovirus', 'small', 'aerosol', 'chamber', 'experiment', 'conduct', 'decrease', 'concentration', 'rhinovirus', 'determine', 'effect', 'uv', 'irradiation', 'detection', 'rhinoviral', 'aerosol', 'conduct', 'experiment', 'expose', 'aerosol', 'uv', 'dose', 'mj', 'aerosol', 'collect', 'teflon', 'filter', 'rhinovirus', 'recover', 'qiagen', 'avl', 'buffer', 'qiagen', 'qiaamp', 'viral', 'rna', 'kit', 'qiagen', 'valencia', 'california', 'follow', 'semi', 'nested', 'rt', 'pcr', 'detection', 'gel', 'electrophoresis', 'result', 'obtain', 'positive', 'result', 'filter', 'sample', 'collect', 'aerosolized', 'rhinovirus', 'ultraviolet', 'irradiation', 'airborne', 'virus', 'dos', 'great', 'upper', 'room', 'uv', 'germicidal', 'irradiation', 'application', 'inhibit', 'subsequent', 'detection', 'rt', 'pcr', 'assay', 'conclusion', 'air', 'sampling', 'extraction', 'methodology', 'develop', 'study', 'applicable', 'detection', 'rhinovirus', 'airborne', 'virus', 'indoor', 'air', 'office', 'school', 'method', 'distinguish', 'uv', 'inactivated', 'virus', 'infectious', 'viral', 'particle']

# %%
def process_text(input_text):
    processed_text = [
        token.lemma_.lower() 
        for token in nlp(input_text) 
        if not token.is_stop and not token.is_punct and token.is_alpha]
    return processed_text

# %%
index = {} # word: {doc_id: {"title": frequency, "body": frequency}}
doc_length_dict = {} # doc_id: {"title": len, "body": len}

def update_counts(spacy_doc, field, doc_id):
    doc_length_dict[doc_id][field] = len(spacy_doc)
    
    for token in spacy_doc:
        if not token.is_stop and (token.is_alpha or token.text in ["-"]):
            word = token.lemma_.lower()
            
            if word not in index:
                index[word] = {}
            if doc_id not in index[word]:
                index[word][doc_id] = {"title": 0, "body": 0}
            
            index[word][doc_id][field] += 1


docs = list(dataset.docs_iter())
titles = [d.title for d in docs]
abstracts = [d.abstract for d in docs]

print("Processing documents...")

n = 0
for doc_obj, title_doc, abs_doc in tqdm(zip(docs, nlp.pipe(titles), nlp.pipe(abstracts)), total=len(docs)):
    n+= 1
    if n >5:
        break
    doc_id = doc_obj.doc_id
    print(doc_id)
    
    doc_length_dict[doc_id] = {"title": 0, "body": 0}
    
    update_counts(title_doc, "title", doc_id)
    update_counts(abs_doc, "body", doc_id)

print(f"Index built with {len(index)} unique terms.")
# Out:
# Processing documents...
#   0%|                                                                              | 5/51078 [00:03<8:46:04,  1.62it/s]
# xqhn0vbp
# gi6uaa83
# le0ogx1s
# fy4w7xz8
# 0qaoam29
# Index built with 326 unique terms.

# %%
index
# Out:
# {'airborne': {'xqhn0vbp': {'title': 1, 'body': 3}},
#  'rhinovirus': {'xqhn0vbp': {'title': 1, 'body': 9}},
#  'detection': {'xqhn0vbp': {'title': 2, 'body': 4}},
#  'effect': {'xqhn0vbp': {'title': 1, 'body': 1}},
#  'ultraviolet': {'xqhn0vbp': {'title': 1, 'body': 1}},
#  'irradiation': {'xqhn0vbp': {'title': 1, 'body': 3}},
#  'semi': {'xqhn0vbp': {'title': 1, 'body': 1}},
#  '-': {'xqhn0vbp': {'title': 2, 'body': 4},
#   'fy4w7xz8': {'title': 0, 'body': 11},
#   '0qaoam29': {'title': 0, 'body': 2}},
#  'nested': {'xqhn0vbp': {'title': 1, 'body': 1}},
#  'rt': {'xqhn0vbp': {'title': 1, 'body': 2}},
#  'pcr': {'xqhn0vbp': {'title': 1, 'body': 2},
#   'fy4w7xz8': {'title': 0, 'body': 1}},
#  'assay': {'xqhn0vbp': {'title': 1, 'body': 1}},
#  'background': {'xqhn0vbp': {'title': 0, 'body': 1},
#   'fy4w7xz8': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'common': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'cause': {'xqhn0vbp': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 3}},
#  'upper': {'xqhn0vbp': {'title': 0, 'body': 2}},
#  'respiratory': {'xqhn0vbp': {'title': 0, 'body': 1},
#   'fy4w7xz8': {'title': 1, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'tract': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'infection': {'xqhn0vbp': {'title': 0, 'body': 1},
#   'fy4w7xz8': {'title': 1, 'body': 5}},
#  'implicate': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'asthma': {'xqhn0vbp': {'title': 0, 'body': 2}},
#  'exacerbation': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'possibly': {'xqhn0vbp': {'title': 0, 'body': 1},
#   'fy4w7xz8': {'title': 0, 'body': 1}},
#  'death': {'xqhn0vbp': {'title': 0, 'body': 1},
#   'le0ogx1s': {'title': 1, 'body': 1}},
#  'method': {'xqhn0vbp': {'title': 0, 'body': 5}},
#  'transmission': {'xqhn0vbp': {'title': 0, 'body': 4}},
#  'dispute': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'study': {'xqhn0vbp': {'title': 0, 'body': 3},
#   'fy4w7xz8': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'demonstrate': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'aerosol': {'xqhn0vbp': {'title': 0, 'body': 5}},
#  'likely': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'adult': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'step': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'possible': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'develop': {'xqhn0vbp': {'title': 0, 'body': 2},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'detect': {'xqhn0vbp': {'title': 0, 'body': 2}},
#  'aerosolized': {'xqhn0vbp': {'title': 0, 'body': 2}},
#  'extend': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'exist': {'xqhn0vbp': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 2}},
#  'technology': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'infectious': {'xqhn0vbp': {'title': 0, 'body': 2},
#   'fy4w7xz8': {'title': 0, 'body': 1}},
#  'agent': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'nasal': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'specimen': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'aerosolize': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'small': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'chamber': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'experiment': {'xqhn0vbp': {'title': 0, 'body': 2}},
#  'conduct': {'xqhn0vbp': {'title': 0, 'body': 2}},
#  'decrease': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'concentration': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'determine': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'uv': {'xqhn0vbp': {'title': 0, 'body': 4}},
#  'rhinoviral': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'expose': {'xqhn0vbp': {'title': 0, 'body': 1},
#   'fy4w7xz8': {'title': 0, 'body': 2}},
#  'dose': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'mj': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'collect': {'xqhn0vbp': {'title': 0, 'body': 2}},
#  'teflon': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'filter': {'xqhn0vbp': {'title': 0, 'body': 2}},
#  'recover': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'qiagen': {'xqhn0vbp': {'title': 0, 'body': 3}},
#  'avl': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'buffer': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'qiaamp': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'viral': {'xqhn0vbp': {'title': 0, 'body': 2}},
#  'rna': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'kit': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'valencia': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'california': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'follow': {'xqhn0vbp': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'gel': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'electrophoresis': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'result': {'xqhn0vbp': {'title': 0, 'body': 2},
#   'fy4w7xz8': {'title': 0, 'body': 3},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'obtain': {'xqhn0vbp': {'title': 0, 'body': 1},
#   'fy4w7xz8': {'title': 0, 'body': 1}},
#  'positive': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'sample': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'virus': {'xqhn0vbp': {'title': 0, 'body': 3},
#   'gi6uaa83': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 2}},
#  'dos': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'great': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'room': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'germicidal': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'application': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'inhibit': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'subsequent': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'conclusion': {'xqhn0vbp': {'title': 0, 'body': 1},
#   'fy4w7xz8': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'air': {'xqhn0vbp': {'title': 0, 'body': 2}},
#  'sampling': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'extraction': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'methodology': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'applicable': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'indoor': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'office': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'school': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'distinguish': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'inactivated': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'particle': {'xqhn0vbp': {'title': 0, 'body': 1}},
#  'discover': {'gi6uaa83': {'title': 1, 'body': 0}},
#  'human': {'gi6uaa83': {'title': 1, 'body': 3},
#   'fy4w7xz8': {'title': 0, 'body': 1}},
#  'history': {'gi6uaa83': {'title': 1, 'body': 1}},
#  'stomach': {'gi6uaa83': {'title': 1, 'body': 0}},
#  'bacteria': {'gi6uaa83': {'title': 1, 'body': 0}},
#  'recent': {'gi6uaa83': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'analysis': {'gi6uaa83': {'title': 0, 'body': 1},
#   'fy4w7xz8': {'title': 0, 'body': 1}},
#  'pathogen': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'reveal': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'evolutionary': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'congruent': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'hypothesized': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'pattern': {'gi6uaa83': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'ancient': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'modern': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'population': {'gi6uaa83': {'title': 0, 'body': 2},
#   'fy4w7xz8': {'title': 0, 'body': 3}},
#  'migration': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'phylogenetic': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'tree': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'strain': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'bacterium': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'helicobacter': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'pylori': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'polyoma': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'jc': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'take': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'geographically': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'diverse': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'group': {'gi6uaa83': {'title': 0, 'body': 1},
#   'fy4w7xz8': {'title': 0, 'body': 7}},
#  'being': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'correlate': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'closely': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'relationship': {'gi6uaa83': {'title': 0, 'body': 1}},
#  'find': {'gi6uaa83': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 2}},
#  'new': {'le0ogx1s': {'title': 1, 'body': 2},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'recruit': {'le0ogx1s': {'title': 1, 'body': 1}},
#  'army': {'le0ogx1s': {'title': 1, 'body': 1}},
#  'man': {'le0ogx1s': {'title': 1, 'body': 1}},
#  'john': {'le0ogx1s': {'title': 0, 'body': 1}},
#  'bunyan': {'le0ogx1s': {'title': 0, 'body': 1}},
#  'memorable': {'le0ogx1s': {'title': 0, 'body': 1}},
#  'phrase': {'le0ogx1s': {'title': 0, 'body': 1}},
#  'fear': {'le0ogx1s': {'title': 0, 'body': 1}},
#  'face': {'le0ogx1s': {'title': 0, 'body': 2}},
#  'wear': {'le0ogx1s': {'title': 0, 'body': 1}},
#  'surgical': {'le0ogx1s': {'title': 0, 'body': 1}},
#  'mask': {'le0ogx1s': {'title': 0, 'body': 1}},
#  'association': {'fy4w7xz8': {'title': 1, 'body': 2}},
#  'hla': {'fy4w7xz8': {'title': 1, 'body': 11}},
#  'class': {'fy4w7xz8': {'title': 1, 'body': 4}},
#  'severe': {'fy4w7xz8': {'title': 1, 'body': 3},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'acute': {'fy4w7xz8': {'title': 1, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'syndrome': {'fy4w7xz8': {'title': 1, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'coronavirus': {'fy4w7xz8': {'title': 1, 'body': 4},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'leukocyte': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'antigen': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'system': {'fy4w7xz8': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'widely': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'strategy': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'search': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'etiology': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'disease': {'fy4w7xz8': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 2}},
#  'autoimmune': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'disorder': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'taiwan': {'fy4w7xz8': {'title': 0, 'body': 2}},
#  'epidemic': {'fy4w7xz8': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 1, 'body': 7}},
#  'sars': {'fy4w7xz8': {'title': 0, 'body': 13},
#   '0qaoam29': {'title': 1, 'body': 7}},
#  'health': {'fy4w7xz8': {'title': 0, 'body': 4}},
#  'care': {'fy4w7xz8': {'title': 0, 'body': 4}},
#  'worker': {'fy4w7xz8': {'title': 0, 'body': 4}},
#  'infect': {'fy4w7xz8': {'title': 0, 'body': 3},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'effort': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'establish': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'screening': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'program': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'high': {'fy4w7xz8': {'title': 0, 'body': 4},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'risk': {'fy4w7xz8': {'title': 0, 'body': 3}},
#  'personal': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'distribution': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'ii': {'fy4w7xz8': {'title': 0, 'body': 3}},
#  'allele': {'fy4w7xz8': {'title': 0, 'body': 5}},
#  'case': {'fy4w7xz8': {'title': 0, 'body': 4}},
#  'control': {'fy4w7xz8': {'title': 0, 'body': 2}},
#  'examine': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'presence': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'genetic': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'susceptibly': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'resistance': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'methods': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'type': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'ssop': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'perform': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'probable': {'fy4w7xz8': {'title': 0, 'body': 6}},
#  'fever': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'patient': {'fy4w7xz8': {'title': 0, 'body': 7},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'exclude': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'later': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'non': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'infected': {'fy4w7xz8': {'title': 0, 'body': 2}},
#  'additional': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'set': {'fy4w7xz8': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'normal': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'healthy': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'unrelated': {'fy4w7xz8': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'taiwanese': {'fy4w7xz8': {'title': 0, 'body': 2}},
#  'woolf': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'haldane': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'odds': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'ratio': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'correct': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'p': {'fy4w7xz8': {'title': 0, 'body': 4}},
#  'value': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'pc': {'fy4w7xz8': {'title': 0, 'body': 4}},
#  'tail': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'fisher': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'exact': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'test': {'fy4w7xz8': {'title': 0, 'body': 2}},
#  'susceptibility': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'analyze': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'appear': {'fy4w7xz8': {'title': 0, 'body': 3},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'element': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'favor': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'select': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'compare': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'severity': {'fy4w7xz8': {'title': 0, 'body': 2}},
#  'show': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'significantly': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'associate': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'densely': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'populate': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'region': {'fy4w7xz8': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 4}},
#  'genetically': {'fy4w7xz8': {'title': 0, 'body': 2}},
#  'related': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'southern': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'asian': {'fy4w7xz8': {'title': 0, 'body': 2}},
#  'affect': {'fy4w7xz8': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 2}},
#  'spreading': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'recently': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'report': {'fy4w7xz8': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'indigenous': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'people': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'distinct': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'general': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'b': {'fy4w7xz8': {'title': 0, 'body': 4}},
#  'frequency': {'fy4w7xz8': {'title': 0, 'body': 2}},
#  'increase': {'fy4w7xz8': {'title': 0, 'body': 2}},
#  'observe': {'fy4w7xz8': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'significant': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'see': {'fy4w7xz8': {'title': 0, 'body': 1},
#   '0qaoam29': {'title': 0, 'body': 1}},
#  'indicate': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'independent': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'need': {'fy4w7xz8': {'title': 0, 'body': 1}},
#  'double': {'0qaoam29': {'title': 1, 'body': 0}},
#  'model': {'0qaoam29': {'title': 1, 'body': 4}},
#  'propagation': {'0qaoam29': {'title': 1, 'body': 0}},
#  'spread': {'0qaoam29': {'title': 0, 'body': 4}},
#  'guangdong': {'0qaoam29': {'title': 0, 'body': 1}},
#  'province': {'0qaoam29': {'title': 0, 'body': 1}},
#  'rest': {'0qaoam29': {'title': 0, 'body': 1}},
#  'china': {'0qaoam29': {'title': 0, 'body': 1}},
#  'world': {'0qaoam29': {'title': 0, 'body': 1}},
#  'puzzling': {'0qaoam29': {'title': 0, 'body': 1}},
#  'contagion': {'0qaoam29': {'title': 0, 'body': 1}},
#  'behavior': {'0qaoam29': {'title': 0, 'body': 2}},
#  'important': {'0qaoam29': {'title': 0, 'body': 2}},
#  'predict': {'0qaoam29': {'title': 0, 'body': 1}},
#  'future': {'0qaoam29': {'title': 0, 'body': 3}},
#  'present': {'0qaoam29': {'title': 0, 'body': 1}},
#  'outbreak': {'0qaoam29': {'title': 0, 'body': 2}},
#  'implement': {'0qaoam29': {'title': 0, 'body': 1}},
#  'effective': {'0qaoam29': {'title': 0, 'body': 1}},
#  'prophylactic': {'0qaoam29': {'title': 0, 'body': 1}},
#  'measure': {'0qaoam29': {'title': 0, 'body': 2}},
#  'identify': {'0qaoam29': {'title': 0, 'body': 2}},
#  'standard': {'0qaoam29': {'title': 0, 'body': 1}},
#  'susceptible': {'0qaoam29': {'title': 0, 'body': 1}},
#  'removed': {'0qaoam29': {'title': 0, 'body': 1}},
#  'sir': {'0qaoam29': {'title': 0, 'body': 1}},
#  'account': {'0qaoam29': {'title': 0, 'body': 1}},
#  'involve': {'0qaoam29': {'title': 0, 'body': 1}},
#  'superimposed': {'0qaoam29': {'title': 0, 'body': 1}},
#  'hong': {'0qaoam29': {'title': 0, 'body': 1}},
#  'kong': {'0qaoam29': {'title': 0, 'body': 1}},
#  'explore': {'0qaoam29': {'title': 0, 'body': 1}},
#  'situation': {'0qaoam29': {'title': 0, 'body': 1}},
#  'mutant': {'0qaoam29': {'title': 0, 'body': 1}},
#  'change': {'0qaoam29': {'title': 0, 'body': 1}},
#  'tropism': {'0qaoam29': {'title': 0, 'body': 1}},
#  'consequence': {'0qaoam29': {'title': 0, 'body': 1}},
#  'innocuous': {'0qaoam29': {'title': 0, 'body': 1}},
#  'generate': {'0qaoam29': {'title': 0, 'body': 1}},
#  'time': {'0qaoam29': {'title': 0, 'body': 2}},
#  'variant': {'0qaoam29': {'title': 0, 'body': 1}},
#  'property': {'0qaoam29': {'title': 0, 'body': 1}},
#  'similar': {'0qaoam29': {'title': 0, 'body': 1}},
#  'order': {'0qaoam29': {'title': 0, 'body': 1}},
#  'reconcile': {'0qaoam29': {'title': 0, 'body': 1}},
#  'datum': {'0qaoam29': {'title': 0, 'body': 2}},
#  'convenient': {'0qaoam29': {'title': 0, 'body': 1}},
#  'suggest': {'0qaoam29': {'title': 0, 'body': 3}},
#  'milder': {'0qaoam29': {'title': 0, 'body': 1}},
#  'protect': {'0qaoam29': {'title': 0, 'body': 1}},
#  'simultaneously': {'0qaoam29': {'title': 0, 'body': 1}},
#  'suffer': {'0qaoam29': {'title': 0, 'body': 1}},
#  'percentage': {'0qaoam29': {'title': 0, 'body': 1}},
#  'person': {'0qaoam29': {'title': 0, 'body': 1}},
#  'inconsistent': {'0qaoam29': {'title': 0, 'body': 1}},
#  'incomplete': {'0qaoam29': {'title': 0, 'body': 1}},
#  'reflect': {'0qaoam29': {'title': 0, 'body': 1}},
#  'appropriate': {'0qaoam29': {'title': 0, 'body': 1}},
#  'identification': {'0qaoam29': {'title': 0, 'body': 1}},
#  'finally': {'0qaoam29': {'title': 0, 'body': 1}},
#  'framework': {'0qaoam29': {'title': 0, 'body': 1}},
#  'fix': {'0qaoam29': {'title': 0, 'body': 1}},
#  'limit': {'0qaoam29': {'title': 0, 'body': 1}},
#  'development': {'0qaoam29': {'title': 0, 'body': 1}},
#  'allow': {'0qaoam29': {'title': 0, 'body': 1}},
#  'landmark': {'0qaoam29': {'title': 0, 'body': 1}},
#  'useful': {'0qaoam29': {'title': 0, 'body': 1}},
#  'monitoring': {'0qaoam29': {'title': 0, 'body': 1}},
#  'evolution': {'0qaoam29': {'title': 0, 'body': 1}},
#  'precursor': {'0qaoam29': {'title': 0, 'body': 1}},
#  'large': {'0qaoam29': {'title': 0, 'body': 1}},
#  'reservoir': {'0qaoam29': {'title': 0, 'body': 1}},
#  'prompt': {'0qaoam29': {'title': 0, 'body': 1}},
#  'implementation': {'0qaoam29': {'title': 0, 'body': 1}},
#  'precautionary': {'0qaoam29': {'title': 0, 'body': 1}},
#  'weather': {'0qaoam29': {'title': 0, 'body': 1}},
#  'cool': {'0qaoam29': {'title': 0, 'body': 1}}}

# %%
import pickle

data_to_save = {
    "index": index,
    "doc_length_dict": doc_length_dict
}

print("Saving index to disk...")
with open('inverted_index.pkl', 'wb') as f:
    pickle.dump(data_to_save, f, protocol=pickle.HIGHEST_PROTOCOL)

print("Done! File saved as inverted_index.pkl")
# Out:
# Saving index to disk...
# Done! File saved as inverted_index.pkl

# %%
print("Loading index...")
with open('inverted_index.pkl', 'rb') as f:
    loaded_data = pickle.load(f)

index = loaded_data["index"]
doc_length_dict = loaded_data["doc_length_dict"]

print(f"Loaded index with {len(index)} terms.")

# %%
# this notebook is preprocessing before BM25 calculations - check with the group if this is what we want to do.

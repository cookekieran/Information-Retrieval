# %%
import ir_datasets

# %%
dataset = ir_datasets.load("cord19/trec-covid/round3")

# %%
doc_store = dataset.docs_store()
query_store = {q.query_id: q for q in dataset.queries_iter()}

count = 0
for qrel in dataset.qrels_iter():
    if qrel.relevance == 2:
        print("query relevance == 2")
        query = query_store[qrel.query_id]
        doc = doc_store.get(qrel.doc_id)
        
        print(f"SAMPLE {count + 1}")
        print(f"QUERY ID:    {query.query_id}")
        print(f"QUERY TITLE: {query.title}")
        print(f"QUERY DESC:  {query.description}")
        print("-" * 30)
        print(f"MATCHING DOC ID: {doc.doc_id}")
        print(f"DOC TITLE:       {doc.title}")
        print(f"DOC ABSTRACT:    {doc.abstract[:300]}...") # Truncated for readability
        print("\n" + "="*50 + "\n")
        
        count += 1
        if count >= 6:
            break
    
    elif qrel.relevance == 1:
        print("query relevance == 1")
        query = query_store[qrel.query_id]
        doc = doc_store.get(qrel.doc_id)
        
        print(f"SAMPLE {count + 1}")
        print(f"QUERY ID:    {query.query_id}")
        print(f"QUERY TITLE: {query.title}")
        print(f"QUERY DESC:  {query.description}")
        print("-" * 30)
        print(f"MATCHING DOC ID: {doc.doc_id}")
        print(f"DOC TITLE:       {doc.title}")
        print(f"DOC ABSTRACT:    {doc.abstract[:300]}...") # Truncated for readability
        print("\n" + "="*50 + "\n")

        count += 1
        if count >=3:
            continue
# Out:
# query relevance == 1
# SAMPLE 1
# QUERY ID:    1
# QUERY TITLE: coronavirus origin
# QUERY DESC:  what is the origin of COVID-19
# ------------------------------
# MATCHING DOC ID: 0194oljo
# DOC TITLE:       Evidence for zoonotic origins of Middle East respiratory syndrome coronavirus.
# DOC ABSTRACT:    Middle East respiratory syndrome (MERS) is an emerging infectious disease, caused by Middle East respiratory syndrome coronavirus (MERS-CoV) and is considered to be a zoonosis. However, the natural reservoirs of MERS-CoV remain obscure, with bats and camels as the most suspected sources. In this art...
#
# ==================================================
#
# query relevance == 1
# SAMPLE 2
# QUERY ID:    1
# QUERY TITLE: coronavirus origin
# QUERY DESC:  what is the origin of COVID-19
# ------------------------------
# MATCHING DOC ID: 08ds967z
# DOC TITLE:       A novel human coronavirus: Middle East respiratory syndrome human coronavirus
# DOC ABSTRACT:    In 2012, a novel coronavirus, initially named as human coronavirus EMC (HCoV-EMC) but recently renamed as Middle East respiratory syndrome human coronavirus (MERS-CoV), was identified in patients who suffered severe acute respiratory infection and subsequent renal failure that resulted in death. Ong...
#
# ==================================================
#
# query relevance == 1
# SAMPLE 3
# QUERY ID:    1
# QUERY TITLE: coronavirus origin
# QUERY DESC:  what is the origin of COVID-19
# ------------------------------
# MATCHING DOC ID: 0evw0fc5
# DOC TITLE:       Commentary on: The SARS, MERS and novel coronavirus (COVID-19) epidemics, the newest and biggest global health threats: what lessons have we learned? A One Health approach to coronaviruses
# DOC ABSTRACT:    ...
#
# ==================================================
#
# query relevance == 2
# SAMPLE 4
# QUERY ID:    1
# QUERY TITLE: coronavirus origin
# QUERY DESC:  what is the origin of COVID-19
# ------------------------------
# MATCHING DOC ID: 0y34yxlb
# DOC TITLE:       Predicting the evolution Of SARS-Covid-2 in Portugal using an adapted SIR Model previously used in South Korea for the MERS outbreak
# DOC ABSTRACT:    The new coronavirus covid-19 has spread very quickly worldwide, leading the World Health Organization (WHO) to declare a state of pandemic. One of the questions many policy makers, and governments are asking themselves is how the spread is going to evolve in time. In this study, I applied an adapted...
#
# ==================================================
#
# query relevance == 2
# SAMPLE 5
# QUERY ID:    1
# QUERY TITLE: coronavirus origin
# QUERY DESC:  what is the origin of COVID-19
# ------------------------------
# MATCHING DOC ID: 127c5bve
# DOC TITLE:       Decoding the evolution and transmissions of the novel pneumonia coronavirus (SARS-CoV-2 / HCoV-19) using whole genomic data.
# DOC ABSTRACT:    The outbreak of COVID-19 started in mid-December 2019 in Wuhan, China. Up to 29 February 2020, SARS-CoV-2 (HCoV-19 / 2019-nCoV) had infected more than 85 000 people in the world. In this study, we used 93 complete genomes of SARS-CoV-2 from the GISAID EpiFlu TM database to investigate the evolution ...
#
# ==================================================
#
# query relevance == 1
# SAMPLE 6
# QUERY ID:    1
# QUERY TITLE: coronavirus origin
# QUERY DESC:  what is the origin of COVID-19
# ------------------------------
# MATCHING DOC ID: 1dogron2
# DOC TITLE:       The emergence of SARS, MERS and novel SARS-2 coronaviruses in the 21st century
# DOC ABSTRACT:    At the beginning of the 21st century, a new deadly infectious disease known as severe acute respiratory syndrome (SARS) was recognized as a global public health threat. Subsequently, ten years after the initial SARS cases occurred in 2002, new cases of another atypical respiratory disease caused wor...
#
# ==================================================
#
# query relevance == 1
# SAMPLE 7
# QUERY ID:    1
# QUERY TITLE: coronavirus origin
# QUERY DESC:  what is the origin of COVID-19
# ------------------------------
# MATCHING DOC ID: 1spgrrmw
# DOC TITLE:       Molecular aspects of MERS-CoV
# DOC ABSTRACT:    Middle East respiratory syndrome coronavirus (MERS-CoV) is a betacoronavirus which can cause acute respiratory distress in humans and is associated with a relatively high mortality rate. Since it was first identified in a patient who died in a Jeddah hospital in 2012, the World Health Organization h...
#
# ==================================================
#
# query relevance == 1
# SAMPLE 8
# QUERY ID:    1
# QUERY TITLE: coronavirus origin
# QUERY DESC:  what is the origin of COVID-19
# ------------------------------
# MATCHING DOC ID: 1ybj2p1n
# DOC TITLE:       Evolution of severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2) as coronavirus disease 2019 (COVID-19) pandemic: A global health emergency
# DOC ABSTRACT:    Abstract According to data compiled by researchers at Johns Hopkins University in Baltimore, Maryland, more than two and half million cases of coronavirus disease 2019 (COVID-19), caused by a newly discovered virus named severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2), have been confirm...
#
# ==================================================
#
# query relevance == 2
# SAMPLE 9
# QUERY ID:    1
# QUERY TITLE: coronavirus origin
# QUERY DESC:  what is the origin of COVID-19
# ------------------------------
# MATCHING DOC ID: 23yi8so0
# DOC TITLE:       Non-Molecular-Clock-Like Evolution following Viral Origins in Homo sapiens
# DOC ABSTRACT:    Researchers routinely adopt molecular clock assumptions in conducting sequence analyses to estimate dates for viral origins in humans. We used computational methods to examine the extent to which this practice can result in inaccurate ‘retrodiction.’ Failing to account for dynamic molecular evolutio...
#
# ==================================================

# %%
from collections import Counter
import ir_datasets

qrel_counts = Counter(q.query_id for q in dataset.qrels_iter())

print(f"{'Query ID':<10} | {'Total Judgments':<15}")
print("-" * 30)

for q_id in sorted(qrel_counts.keys(), key=int):
    print(f"{q_id:<10} | {qrel_counts[q_id]:<15}")
# Out:
# Query ID   | Total Judgments
# ------------------------------
# 1          | 330
# 2          | 274
# 3          | 339
# 4          | 344
# 5          | 334
# 6          | 326
# 7          | 303
# 8          | 374
# 9          | 357
# 10         | 272
# 11         | 382
# 12         | 359
# 13         | 368
# 14         | 322
# 15         | 436
# 16         | 368
# 17         | 320
# 18         | 285
# 19         | 333
# 20         | 244
# 21         | 339
# 22         | 266
# 23         | 272
# 24         | 263
# 25         | 334
# 26         | 336
# 27         | 300
# 28         | 223
# 29         | 293
# 30         | 221
# 31         | 502
# 32         | 464
# 33         | 367
# 34         | 531
# 35         | 381
# 36         | 194
# 37         | 200
# 38         | 220
# 39         | 170
# 40         | 167
